# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader
from surprise.model_selection import KFold, cross_validate, train_test_split
from tabulate import tabulate

# %% [markdown]
# # Create a KNN Ranking algorithm version

# %%
from surprise import AlgoBase
from surprise import Dataset
from six import iteritems
import heapq
from surprise.prediction_algorithms.predictions import PredictionImpossible

class SymmetricAlgo(AlgoBase):
    """
    This is an abstract class aimed to ease the use of symmetric algorithms.
    A symmetric algorithm is an algorithm that can can be based on users or on
    items indifferently. When the algo is user-based x denotes a user and y an item. 
    Else, it's reversed.
    """
    def __init__(self, sim_options={}, verbose=True, **kwargs):

        AlgoBase.__init__(self, sim_options=sim_options, **kwargs)
        self.verbose = verbose

    def fit(self, trainset):

        AlgoBase.fit(self, trainset)

        ub = self.sim_options['user_based']
        self.n_x = self.trainset.n_users if ub else self.trainset.n_items
        self.n_y = self.trainset.n_items if ub else self.trainset.n_users
        self.xr = self.trainset.ur if ub else self.trainset.ir
        self.yr = self.trainset.ir if ub else self.trainset.ur

        return self

    def switch(self, u_stuff, i_stuff):
        """
        Return x_stuff and y_stuff depending on the user_based field.
        """

        if self.sim_options['user_based']:
            return u_stuff, i_stuff
        else:
            return i_stuff, u_stuff


class RankingKNNBasic(SymmetricAlgo):
    def __init__(self, k=40, min_k=1, sim_options={}, verbose=True, **kwargs):

        SymmetricAlgo.__init__(self, sim_options=sim_options, verbose=verbose,
                               **kwargs)
        self.k = k
        self.min_k = min_k

    def fit(self, trainset):

        SymmetricAlgo.fit(self, trainset)
        self.sim = self.compute_similarities()

        return self

    def estimate(self, u, i):

        if not (self.trainset.knows_user(u) and self.trainset.knows_item(i)):
            raise PredictionImpossible('User and/or item is unknown.')

        x, y = self.switch(u, i)

        neighbors = [(self.sim[x, x2], r) for (x2, r) in self.yr[y]]
        k_neighbors = heapq.nlargest(self.k, neighbors, key=lambda t: t[0])
        
        # compute the sum of similarities
        sum_sim = actual_k = 0
        ratings_from_sim = []
        for (sim, r) in k_neighbors:
            sum_sim += sim
            actual_k += 1
            ratings_from_sim.append(r)

        if actual_k < self.min_k:
            raise PredictionImpossible('Not enough neighbors.')

        est = sum_sim
    
        details = {'actual_k': actual_k}
        return est, details

# %% [markdown]
# # Define a way to get precision and recall

# %%
from collections import defaultdict

def precision_recall_at_k(predictions, k=10, threshold=3.5):
    '''Return precision and recall at k metrics for each user.'''

    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))

    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():

        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)

        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)

        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])

        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r >= threshold) and (est >= threshold))
                              for (est, true_r) in user_ratings[:k])

        # Precision@K: Proportion of recommended items that are relevant
        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 1

        # Recall@K: Proportion of relevant items that are recommended
        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 1

    return precisions, recalls

# %% [markdown]
# # Read and load data

# %%
# Read both the datasets from the files using pandas
movielens_df = pd.read_csv("../data/u.data", sep="\t", header=None)
movielens_df.columns = ["userID", "itemID", "rating", "timestamp"]
pda_df = pd.read_csv("../data/train-PDA2018.csv", sep=",")
print(movielens_df.head())
print("\n\n")
print(pda_df.head())
# Out:
#    userID  itemID  rating  timestamp
# 0     196     242       3  881250949
# 1     186     302       3  891717742
# 2      22     377       1  878887116
# 3     244      51       2  880606923
# 4     166     346       1  886397596
#
#
#
#    userID  itemID  rating  timeStamp
# 0       5     648       5  978297876
# 1       5    1394       5  978298237
# 2       5    3534       5  978297149
# 3       5     104       4  978298558
# 4       5    2735       5  978297919

# %%
# Create the training datasets using Surprise's reader class
reader = Reader(rating_scale=(1,5)) # We have ratings from 1 to 5 so we create the rating scale

# Load the data from the dataframes
movielens_dataset = Dataset.load_from_df(movielens_df.iloc[:,0:3], reader)
pda_dataset = Dataset.load_from_df(pda_df.iloc[:,0:3], reader)

# Build full trainsets to print out the data loaded above
mls_train = movielens_dataset.build_full_trainset()
pda_train = pda_dataset.build_full_trainset()

# Print out some basic information about the datasets
print("General information on the training sets we will be using \n")
print("1) Number of items in each dataset", " ML100k:", mls_train.n_items, "PDA:", pda_train.n_items)
print("2) Number of users in each dataset", " ML100k:", mls_train.n_users, "PDA:", pda_train.n_users)
print("3) Number of ratings in each dataset", " ML100k:", mls_train.n_ratings, "PDA:", pda_train.n_ratings)
print("4) Mean rating", " ML100k:", mls_train.global_mean, "PDA:", pda_train.global_mean)
# Out:
# General information on the training sets we will be using
#
# 1) Number of items in each dataset  ML100k: 1682 PDA: 1824
# 2) Number of users in each dataset  ML100k: 943 PDA: 5690
# 3) Number of ratings in each dataset  ML100k: 100000 PDA: 470711
# 4) Mean rating  ML100k: 3.52986 PDA: 3.638361967321775

# %%
kf = KFold(5)
algo = RankingKNNBasic(k=80, sim_options={'name': 'cosine', 'user_based': True})
mls_train, mls_test = train_test_split(data=movielens_dataset, test_size=0.2)

algo.fit(mls_train)
predictions = algo.test(mls_test)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# /Users/Geri/.local/share/virtualenvs/recsys2020_project-EWQ0OJVi/lib/python3.7/site-packages/ipykernel_launcher.py:79: RuntimeWarning: divide by zero encountered in double_scalars

# %%
predictions
# Out:
# [Prediction(uid=144, iid=327, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=181, iid=1049, r_ui=1.0, est=5, details={'actual_k': 19, 'was_impossible': False}),
#  Prediction(uid=747, iid=494, r_ui=5.0, est=5, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid=145, iid=298, r_ui=1.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=363, iid=559, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=119, iid=1265, r_ui=3.0, est=5, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid=406, iid=469, r_ui=4.0, est=5, details={'actual_k': 54, 'was_impossible': False}),
#  Prediction(uid=894, iid=289, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=255, iid=121, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=535, iid=179, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=59, iid=147, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=37, iid=7, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=889, iid=33, r_ui=5.0, est=5, details={'actual_k': 70, 'was_impossible': False}),
#  Prediction(uid=896, iid=1, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=524, iid=501, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=201, iid=121, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=151, iid=277, r_ui=4.0, est=5, details={'actual_k': 55, 'was_impossible': False}),
#  Prediction(uid=230, iid=140, r_ui=3.0, est=5, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid=798, iid=391, r_ui=3.0, est=5, details={'actual_k': 47, 'was_impossible': False}),
#  Prediction(uid=276, iid=518, r_ui=4.0, est=5, details={'actual_k': 70, 'was_impossible': False}),
#  Prediction(uid=894, iid=462, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=391, iid=462, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=313, iid=494, r_ui=3.0, est=5, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid=622, iid=1231, r_ui=2.0, est=5, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid=301, iid=210, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=916, iid=583, r_ui=4.0, est=5, details={'actual_k': 27, 'was_impossible': False}),
#  Prediction(uid=450, iid=765, r_ui=3.0, est=5, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid=896, iid=245, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=453, iid=780, r_ui=3.0, est=5, details={'actual_k': 55, 'was_impossible': False}),
#  Prediction(uid=716, iid=480, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=188, iid=455, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=104, iid=713, r_ui=3.0, est=5, details={'actual_k': 58, 'was_impossible': False}),
#  Prediction(uid=58, iid=222, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=655, iid=1198, r_ui=3.0, est=5, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid=385, iid=521, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=393, iid=356, r_ui=3.0, est=5, details={'actual_k': 79, 'was_impossible': False}),
#  Prediction(uid=598, iid=343, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=789, iid=150, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=100, iid=895, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=504, iid=616, r_ui=4.0, est=5, details={'actual_k': 53, 'was_impossible': False}),
#  Prediction(uid=842, iid=749, r_ui=4.0, est=5, details={'actual_k': 35, 'was_impossible': False}),
#  Prediction(uid=309, iid=324, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=460, iid=127, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=632, iid=58, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=588, iid=645, r_ui=5.0, est=5, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid=937, iid=301, r_ui=1.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=297, iid=117, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=689, iid=222, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=936, iid=1368, r_ui=5.0, est=5, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid=268, iid=386, r_ui=2.0, est=5, details={'actual_k': 66, 'was_impossible': False}),
#  Prediction(uid=126, iid=316, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=301, iid=67, r_ui=2.0, est=5, details={'actual_k': 75, 'was_impossible': False}),
#  Prediction(uid=453, iid=941, r_ui=2.0, est=5, details={'actual_k': 37, 'was_impossible': False}),
#  Prediction(uid=892, iid=825, r_ui=4.0, est=5, details={'actual_k': 62, 'was_impossible': False}),
#  Prediction(uid
r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=725, iid=333, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=844, iid=553, r_ui=4.0, est=5, details={'actual_k': 49, 'was_impossible': False}),
#  Prediction(uid=807, iid=127, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=442, iid=177, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=763, iid=845, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=875, iid=462, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=318, iid=659, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=484, iid=419, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=716, iid=135, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=795, iid=217, r_ui=1.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=385, iid=945, r_ui=5.0, est=5, details={'actual_k': 29, 'was_impossible': False}),
#  Prediction(uid=435, iid=240, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=588, iid=832, r_ui=1.0, est=5, details={'actual_k': 15, 'was_impossible': False}),
#  Prediction(uid=571, iid=32, r_ui=2.0, est=5, details={'actual_k': 67, 'was_impossible': False}),
#  Prediction(uid=705, iid=419, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=187, iid=423, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=325, iid=525, r_ui=5.0, est=5, details={'actual_k': 58, 'was_impossible': False}),
#  Prediction(uid=366, iid=637, r_ui=5.0, est=5, details={'actual_k': 31, 'was_impossible': False}),
#  Prediction(uid=181, iid=981, r_ui=1.0, est=5, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid=193, iid=328, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=365, iid=222, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=731, iid=1, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=488, iid=605, r_ui=3.0, est=5, details={'actual_k': 23, 'was_impossible': False}),
#  Prediction(uid=280, iid=294, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=588, iid=289, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=60, iid=484, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=342, iid=26, r_ui=2.0, est=5, details={'actual_k': 57, 'was_impossible': False}),
#  Prediction(uid=312, iid=525, r_ui=5.0, est=5, details={'actual_k': 58, 'was_impossible': False}),
#  Prediction(uid=621, iid=270, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=5, iid=389, r_ui=1.0, est=5, details={'actual_k': 21, 'was_impossible': False}),
#  Prediction(uid=424, iid=689, r_ui=1.0, est=5, details={'actual_k': 71, 'was_impossible': False}),
#  Prediction(uid=551, iid=692, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=405, iid=1545, r_ui=2.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid=625, iid=202, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=840, iid=511, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=468, iid=89, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=140, iid=988, r_ui=3.0, est=5, details={'actual_k': 68, 'was_impossible': False}),
#  Prediction(uid=807, iid=121, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=378, iid=1009, r_ui=3.0, est=5, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid=936, iid=1315, r_ui=3.0, est=5, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid=405, iid=1290, r_ui=2.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid=540, iid=1, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=313, iid=326, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=508, iid=186, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=399, iid=813, r_ui=3.0, est=5, details={'actual_k': 48, 'was_impossible': False}),
#  Prediction(uid=666, iid=216, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=495, iid=1469, r_ui=5.0, est=5, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid=201, iid=518, r_ui=4.0, est=5, details={'actual_k': 70, 'was_impossible': False}),
#  Prediction(uid=85, iid=284, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=776, iid=603, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=539, iid=661, r_ui=5.0, est=5, details={'actual_k': 68, 'was_impossible': False}),
#  Prediction(uid=429, iid=234, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=291, iid=412, r_ui=3.0, est=5, details={'actual_k': 79, 'was_impossible': False}),
#  Prediction(uid=827, iid=358, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=896, iid=1074, r_ui=2.0, est=5, details={'actual_k': 58, 'was_impossible': False}),
#  Prediction(uid=483, iid=12, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=919, iid=22, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=775, iid=887, r_ui=4.0, est=5, details={'actual_k': 52, 'was_impossible': False}),
#  Prediction(uid=83, iid=298, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=535, iid=98, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=508, iid=88, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=194, iid=566, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=326, iid=177, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=573, iid=185, r_ui=3.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=357, iid=1095, r_ui=3.0, est=5, details={'actual_k': 24, 'was_impossible': False}),
#  Prediction(uid=503, iid=174, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=868, iid=50, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=658, iid=45, r_ui=5.0, est=5, details={'actual_k': 56, 'was_impossible': False}),
#  Prediction(uid=270, iid=83, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=551, iid=366, r_ui=5.0, est=5, details={'actual_k': 39, 'was_impossible': False}),
#  Prediction(uid=479, iid=182, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=181, iid=763, r_ui=1.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=787, iid=681, r_ui=3.0, est=5, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid=277, iid=302, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=643, iid=1065, r_ui=4.0, est=5, details={'actual_k': 46, 'was_impossible': False}),
#  Prediction(uid=831, iid=250, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=601, iid=318, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=323, iid=22, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=276, iid=449, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=854, iid=511, r_ui=4.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=263, iid=333, r_ui=2.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=53, iid=15, r_ui=5.0, est=5, details={'actual_k': 80, 'was_impossible': False}),
#  Prediction(uid=417, iid=1215, r_ui=2.0, est=5, details={'actual_k': 23, 'was_impossible': False}),
#  ...]

# %%
pres_5, recs_5 = precision_recall_at_k(predictions, k=5)

# %%
pre_5 = np.array([pres_5[k] for k in pres_5.keys()]).mean()
rec_5 = np.array([recs_5[k] for k in recs_5.keys()]).mean()
print(pre_5, rec_5)
# Out:
# 0.5737539766702014 0.47020495974858195
